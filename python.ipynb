# %% [markdown]
# <a href="https://colab.research.google.com/github/santoshiranabhat02/AI-bootcamp/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world');
# Out:
# Hello world

# %% [markdown]
# listing(mutable hetrogeneous), ascessing in continuous memory location

# %%
numbers=[1,7,6,4,'santoshi',5];
print(numbers[0])
print(numbers[-2])
print(numbers[-1])
# Out:
# 1
# santoshi
# 5

# %% [markdown]
# Functions
# sorting -- .sort()
# append -- .append()
# removing-- .remove()

# %%
numbers=[1,7,6,4,5];
numbers.sort();
print(numbers);

numbers.remove(1);
print(numbers);

numbers.append(1);
print(numbers);
# Out:
# [1, 4, 5, 6, 7]
# [4, 5, 6, 7]
# [4, 5, 6, 7, 1]

# %% [markdown]
# list comprehension

# %%
even=[num for num in range(0,10) if num%2==0]
print(even)
# Out:
# [0, 2, 4, 6, 8]

# %%
square=[num**2 for num in range(0,10) ]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# cerating dictianary[ here in code (rojo,2,3) are keys]

# %%
colors={'rojo':'red','1':'blue','3':'green'}
print(colors['rojo']);
print(colors['1']);
print(colors['3']);
# Out:
# red
# blue
# green

# %% [markdown]
# tuple(immutable, hetrogeneous)-----unchangable items

# %%
colors=(255,255,255) #white
colors1=(0,0,0) #black
print(colors[2])
# Out:
# 255

# %% [markdown]
# Set(like set in maths)

# %%
random=[1,2,3,4,5,5,6,6]
print(set(random))

random1='ram'
print(set(random1))

random2='harrry'
print(set(random2))
# Out:
# {1, 2, 3, 4, 5, 6}
# {'a', 'r', 'm'}
# {'h', 'a', 'r', 'y'}
